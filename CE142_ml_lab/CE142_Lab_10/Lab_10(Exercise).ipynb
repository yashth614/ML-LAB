# %% [markdown]
# # Run PCA on IRIS dataset visulize the output in 2-D using principal of components and note sown your observations

# %%
# load the Iris dataset and the necessary libraries:

from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Apply PCA to reduce the dimensionality of the dataset from 4 to 2 dimensions

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
# plot the first two principal components against each other

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='viridis')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Iris dataset PCA')
plt.show()
